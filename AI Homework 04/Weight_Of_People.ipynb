# %% [markdown]
# <a href="https://colab.research.google.com/github/UTEDungNguyen/AI-Homework04/blob/main/Weight_Of_People.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=b529fe1e40da6e7d74c849e31c3d5efac31352f60d9d715267ad86ba9818cbdd
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
from matplotlib.legend import time
import matplotlib
from skfuzzy.control.controlsystem import ControlSystemSimulation
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
universe = np.linspace(0,100,101)
weight = ctrl.Antecedent(universe,'weight')

weight['VL']= fuzzy.trimf(weight.universe,[0,0,30])
weight['L']= fuzzy.trimf(weight.universe,[30,37,45])
weight['A']=fuzzy.trimf(weight.universe,[45,52,60])
weight['H']=fuzzy.trimf(weight.universe,[60,67,75])
weight['VH']=fuzzy.trimf(weight.universe,[75,100,100])
weight.view()
